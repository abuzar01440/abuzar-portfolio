# %% [markdown]
# <a href="https://colab.research.google.com/github/abuzar01440/abuzar-portfolio/blob/main/Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Summarization

# %% [markdown]
# ```
#     !pip install transformers
#     !pip install torch
# ```

# %%
# libraries
from transformers.utils import logging
logging.set_verbosity_error()
from transformers import pipeline
import torch

# %% [markdown]
# ### Build the `summarization` pipeline using 🤗 Transformers Library

# %%
summarizer = pipeline(task="summarization",
                      model="facebook/bart-large-cnn",
                      torch_dtype=torch.bfloat16)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# **Bfloat16** is a numerical data type that represents numbers using 16 bits (half the precision of a standard single-precision floating-point number, which uses 32 bits).
# It offers a balance between storage efficiency and computational performance compared to full-precision (32-bit) floating-point numbers.
#
# * Benefits for LLMs*
#
# Reduced Memory Footprint: Since bfloat16 numbers take up half the space, they can significantly reduce the memory required to store the massive parameters and activations within an LLM. This is crucial for training and deploying large models on resource-constrained hardware.
# Potential Speedup: In some cases, bfloat16 operations can achieve faster execution on hardware that supports them with specialized instructions. This can lead to quicker training and inference times for LLMs.

# %% [markdown]
# Model info: ['bart-large-cnn'](https://huggingface.co/facebook/bart-large-cnn)

# %%
text = """The rivalry between the Pakistan Cricket Board (PCB) and the Board of Control for Cricket in India (BCCI)
 burns with an intensity that transcends the sport itself. Often referred to as the "Battleground,"
  matches between these two neighboring nations become a passionate display of national pride,
  fueled by the historical and political complexities of the region. Every encounter is a highly anticipated spectacle,
   watched by millions with hearts pounding and emotions running high.
   On the field, the competition is fierce and uncompromising.
    Both teams boast a rich cricketing heritage,
    with world-class players who have etched their names in cricketing folklore.
    Pakistan currently leads the dance in One Day Internationals (ODIs),
     having emerged victorious in a remarkable 73 matches compared to India's 57 wins.
      This dominance is particularly intriguing given India's overall success in ICC tournaments.
       However, the recent past has witnessed a shift in momentum.
        India has displayed a resurgent form in ODIs against Pakistan,
        culminating in a convincing win at the 2023 Cricket World Cup.
          With both teams constantly evolving and brimming with young talent,
          the future of this enthralling cricketing rivalry promises many more chapters filled with nail-biting finishes,
          heart-stopping moments, and passionate displays of fanaticism,
           making it one of the most captivating rivalries in the cricketing world."""

# %%
summary = summarizer(text,
                     min_length=101,
                     max_length=150)

# %%
summary
# Out:
# [{'summary_text': "The rivalry between the Pakistan Cricket Board and the Board of Control for Cricket in India burns with an intensity that transcends the sport itself. Pakistan currently leads the dance in One Day Internationals (ODIs), having emerged victorious in a remarkable 73 matches compared to India's 57 wins. However, the recent past has witnessed a shift in momentum. India has displayed a resurgent form in ODIs against Pakistan, culminating in a convincing win at the 2023 Cricket World Cup. With both teams constantly evolving and brimming with young talent, the future of this enthralling cricketing rivalry promises many more chapters filled with nail-biting finishes."}]

# %% [markdown]
# ## Another model

# %%
summarizer_1 = pipeline("summarization",
                        "Falconsai/text_summarization",
                        torch_dtype=torch.bfloat16)
# Out:
# config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
text_1 ="""
The cricketing rivalry between England and Australia, immortalized in the Ashes series, is a saga that transcends mere competition. Often referred to as "The Old Enemy," this contest stretches back to the 19th century, its roots intertwined with the complexities of colonial history. It's a clash of titans, fueled by a mutual respect bordering on obsession with cricketing supremacy. On the field, the battles are captivating narratives spun with willow and leather. England's famed batting elegance, honed on green pitches, often collides with Australia's ruthless pace attacks accustomed to unforgiving bounce. The result? Unpredictable, enthralling matches that leave fans on the edge of their seats, forever yearning for more.

This captivating rivalry extends beyond the iconic Ashes series. The One Day International (ODI) battles between these two powerhouses are equally captivating spectacles, albeit with a slightly different statistical landscape. Here, Australia holds a narrow lead, having emerged victorious in 142 ODIs compared to England's 128 wins. However, recent years have witnessed a shift. England's aggressive ODI approach, spearheaded by the likes of Jos Buttler and Jonny Bairstow, has led to some close series and nerve-wracking encounters that have redefined the dynamic of this historic rivalry.

The England-Australia ODI rivalry is more than just statistics and scorecards. It's a captivating drama that unfolds with every ball bowled and every run scored. It's a battle of wills, a clash of styles, and a platform for exceptional cricketing talent. The passionate Barmy Army trading chants with the boisterous Yellow Brigade in the stands adds another layer of intensity to the atmosphere. Every encounter, be it a high-scoring thriller or a low-scoring nail-biter, is a must-watch event for fans around the globe. This rivalry promises to keep evolving with each generation of players, ensuring its place as one of the most captivating spectacles in the cricketing world."""

# %%
summary_1 = summarizer(text_1,
                     min_length=121,
                     max_length=222)

# %%
summary_1
# Out:
# [{'summary_text': "The cricketing rivalry between England and Australia stretches back to the 19th century. The One Day International (ODI) battles between these two powerhouses are equally captivating. Australia holds a narrow lead, having emerged victorious in 142 ODIs compared to England's 128 wins. England's aggressive ODI approach, spearheaded by the likes of Jos Buttler and Jonny Bairstow, has led to some close series and nerve-wracking encounters. The passionate Barmy Army trading chants with the boisterous Yellow Brigade in the stands adds another layer of intensity to the atmosphere. This rivalry promises to keep evolving with each generation of players, ensuring its place as one of the most captivating spectacles in the cricketing world."}]

# %%
summary_text = summary_1[0]['summary_text']
summary_text
# Out:
# "The cricketing rivalry between England and Australia stretches back to the 19th century. The One Day International (ODI) battles between these two powerhouses are equally captivating. Australia holds a narrow lead, having emerged victorious in 142 ODIs compared to England's 128 wins. England's aggressive ODI approach, spearheaded by the likes of Jos Buttler and Jonny Bairstow, has led to some close series and nerve-wracking encounters. The passionate Barmy Army trading chants with the boisterous Yellow Brigade in the stands adds another layer of intensity to the atmosphere. This rivalry promises to keep evolving with each generation of players, ensuring its place as one of the most captivating spectacles in the cricketing world."

# %%
len(summary_text.split())
# Out:
# 112
