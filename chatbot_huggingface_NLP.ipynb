# %% [markdown]
# <a href="https://colab.research.google.com/github/abuzar01440/abuzar-portfolio/blob/main/chatbot_huggingface_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Natural Language Processing (NLP)

# %% [markdown]
#     !pip install transformers

# %% [markdown]
# ### Build the `chatbot` pipeline using 🤗 Transformers Library

# %%
from transformers.utils import logging
logging.set_verbosity_error()

# %%
from transformers import pipeline

# %% [markdown]
# - Define the conversation pipeline

# %%
chatbot = pipeline(task="conversational",
                   model="facebook/blenderbot-400M-distill")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/730M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/127k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/62.9k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# ...

# %% [markdown]
# Info about ['blenderbot-400M-distill'](https://huggingface.co/facebook/blenderbot-400M-distill)

# %%
user_message = """
give me suggestions how to celebrate my birthday and recommend some Indian food for a dinner
"""

# %%
from transformers import Conversation

# %%
conversation = Conversation(user_message)

# %%
print(conversation)
# Out:
# Conversation id: e1df8d9e-047d-4370-b878-ea47dc9a2b9d
# user:
# give me suggestions how to celebrate my birthday and recommend some Indian food for a dinner

# %%
conversation = chatbot(conversation)

# %%
print(conversation)
# Out:
# Conversation id: e1df8d9e-047d-4370-b878-ea47dc9a2b9d
# user:
# give me suggestions how to celebrate my birthday and recommend some Indian food for a dinner
#
# assistant:  Happy Birthday! What kind of Indian food do you like? There are so many to choose from!

# %%
conversation.add_message(
    {"role": "user",
     "content": """
Please write the name of all spices food
"""
    })

# %%
print(conversation)
# Out:
# Conversation id: e1df8d9e-047d-4370-b878-ea47dc9a2b9d
# user:
# give me suggestions how to celebrate my birthday and recommend some Indian food for a dinner
#
# assistant:  Happy Birthday! What kind of Indian food do you like? There are so many to choose from!
# user:
# Please write the name of all spices food

# %%
conversation = chatbot(conversation)

print(conversation)
# Out:
# Conversation id: e1df8d9e-047d-4370-b878-ea47dc9a2b9d
# user:
# give me suggestions how to celebrate my birthday and recommend some Indian food for a dinner
#
# assistant:  Happy Birthday! What kind of Indian food do you like? There are so many to choose from!
# user:
# Please write the name of all spices food
#
# assistant:  I love curry! It's one of the most popular cuisines in the world!

# %%
conversation.add_message({"role": "user",
     "content": """
Thanks! You are a great Assitant....... Can you please tell me about the Pakistan
"""
    })

# %%
conversation = chatbot(conversation)

print(conversation)
# Out:
# Conversation id: e1df8d9e-047d-4370-b878-ea47dc9a2b9d
# user:
# give me suggestions how to celebrate my birthday and recommend some Indian food for a dinner
#
# assistant:  Happy Birthday! What kind of Indian food do you like? There are so many to choose from!
# user:
# Please write the name of all spices food
#
# assistant:  I love curry! It's one of the most popular cuisines in the world!
# user:
# Thanks! You are a great Assitant....... Can you please tell me about the Pakistan
#
# assistant:  It's a country in South Asia. I've never been there, but I would love to go!

# %% [markdown]
# - [Open LLM Leaderboard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)
# - [LMSYS Chatbot Arena Leaderboard](https://huggingface.co/spaces/lmsys/chatbot-arena-leaderboard)
